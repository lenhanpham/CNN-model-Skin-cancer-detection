# %%
import os
import numpy as np
import pandas as pd
import time
from pathlib import Path

# %pip install silence_tensorflow
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

# %pip install tensorflow
import tensorflow as tf
tf.config.threading.set_intra_op_parallelism_threads(16) 
tf.config.threading.set_inter_op_parallelism_threads(16)
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout, MaxPooling2D, Conv2D, SeparableConv2D
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras import layers

# %pip install scikit-learn 
from sklearn import metrics

import matplotlib.pyplot as plt
# %pip install seaborn 
import seaborn as sns
sns.set()
# Out:
# Collecting silence_tensorflow
#   Downloading silence_tensorflow-1.2.3.tar.gz (7.2 kB)
# done
# Building wheels for collected packages: silence_tensorflow
# done
#   Created wheel for silence_tensorflow: filename=silence_tensorflow-1.2.3-py3-none-any.whl size=6749 sha256=1cab7055d2615c03cb40acdd31692d96ea40242a87b2eb7d7f4853db137ee6f3
#   Stored in directory: /home/azureuser/.cache/pip/wheels/3b/56/66/0a24f17491d94dca2102ee05c2af8eb7d2113d59974f2fa49d
# Successfully built silence_tensorflow
# Installing collected packages: silence_tensorflow
# Successfully installed silence_tensorflow-1.2.3
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (2.17.0)
# Requirement already satisfied: h5py>=3.10.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (3.11.0)
# Collecting ml-dtypes<0.5.0,>=0.3.1
#   Downloading ml_dtypes-0.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 43.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: termcolor>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: keras>=3.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: six>=1.12.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: absl-py>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.65.4)
# Requirement already satisfied: setuptools in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: namex in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: rich in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: optree in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.19)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: markdown>=2.6.8 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Installing collected packages: ml-dtypes
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.0
#     Uninstalling ml_dtypes-0.5.0:
#       Successfully uninstalled ml_dtypes-0.5.0
# Successfully installed ml-dtypes-0.4.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: numpy>=1.19.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: pandas>=1.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: pillow>=6.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2022.5)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
### Download dataset from kagglehub
# %pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fanconic/skin-cancer-malignant-vs-benign")

print("Path to dataset files:", path)
# Out:
# Requirement already satisfied: kagglehub in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (0.3.0)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: tqdm in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from kagglehub) (4.66.4)
# Requirement already satisfied: requests in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests->kagglehub) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests->kagglehub) (1.26.19)
# Note: you may need to restart the kernel to use updated packages.
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.6)
# Path to dataset files: /home/azureuser/.cache/kagglehub/datasets/fanconic/skin-cancer-malignant-vs-benign/versions/4
#  83%|████████▎ | 268M/325M [00:02<00:00, 202MB/s]

# %%
train_dir = path + '/train/'
test_dir = path + '/test/'
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/azureuser/.cache/kagglehub/datasets/fanconic/skin-cancer-malignant-vs-benign/versions/4

# %%
## Visualize a random image in benign dir
import os
random_number = np.random.randint(1000)

train_figure_name = os.listdir(train_dir + 'benign')[random_number]
full_name_train = train_dir + 'benign' + '/' + train_figure_name
image = load_img(full_name_train)
#display(image)
plt.imshow(image)
plt.grid(False)
image.size
# Out:
# (224, 224)

# %%
#Genenrate image data sets for training, validation and test
image_size = (224, 224)
batch_size = 32

augmented_train_gen = ImageDataGenerator(
    rotation_range=30,
    brightness_range=[0.9,1.1],
    zoom_range=0.1,
    fill_mode='constant',
    horizontal_flip=True,
    vertical_flip=True,
    rescale=1./255,
    validation_split=0.2
)

validation_gen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

test_gen = ImageDataGenerator(
    rescale=1./255
)

### training dataset

augmented_train_generator = augmented_train_gen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

augmented_validation_generator = validation_gen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)

augmented_test_generator = test_gen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='binary'
)

for gen, name in zip([augmented_train_generator, augmented_validation_generator, augmented_test_generator],
                     ['train', 'validation', 'test']):
    count_malignant = (gen.classes==1).sum()
    count_benign = (gen.classes==0).sum()
    tot = len(gen.classes)
    print(f"Class distribution in the {name} set")
    print(f"Benign: {count_benign/tot:.0%}")
    print(f"Malignant: {count_malignant/tot:.0%}\n")

#### Define metrics

model_metrics = [
    keras.metrics.Recall(name='recall'),
    keras.metrics.AUC(name='auc'),
    keras.metrics.Precision(name='precision'),
    keras.metrics.BinaryAccuracy(name='accuracy'),
    keras.metrics.TruePositives(name='tp'),
    keras.metrics.TrueNegatives(name='tn'),
    keras.metrics.FalsePositives(name='fp'),
    keras.metrics.FalseNegatives(name='fn'),
]

output_bias = -np.log(count_malignant/count_benign)
print('Initial output bias:', output_bias)
output_bias = tf.keras.initializers.Constant(output_bias)

input_bias = -np.log(1/2)
print('Initiali output bias:', input_bias)
input_bias = tf.keras.initializers.Constant(input_bias)
# Out:
# Found 2110 images belonging to 2 classes.
# Found 527 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# Class distribution in the train set
# Benign: 55%
# Malignant: 45%
#
# Class distribution in the validation set
# Benign: 55%
# Malignant: 45%
#
# Class distribution in the test set
# Benign: 55%
# Malignant: 45%
#
# Initial output bias: 0.1823215567939546
# Initiali output bias: 0.6931471805599453

# %%
### visualize some images

for images, labels in augmented_train_generator:
    malignant_set = [{'image':image, 'label':label} for image, label in zip(images, labels) if label==1]
    benign_set = [{'image':image, 'label':label} for image, label in zip (images, labels) if label==0]

    break

for image_label in malignant_set[:6], benign_set[:6]:
  plt.figure(figsize=(16,3))
  plt.suptitle('Maligant (1)' if int(image_label[0]['label'])==1 else 'Benign (0)')
  for i in range(int(len(malignant_set[:6]))):
    plt.subplot(1, int(len(malignant_set[:6])), i+1)
    plt.imshow(image_label[i]['image'])
    plt.axis('off')
  plt.show()

# %%
pre_trained_Xception = keras.applications.Xception(
    include_top=False,
    weights='imagenet',
    input_shape=(None,None,3)
)

pre_trained_Xception.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "xception"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, None,      │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, None,      │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, None,      │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, None,      │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, None,      │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, None,      │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, None,      │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, None,      │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, None,      │          0 │ block2_sepconv1_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, None,      │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, None,      │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      8,192 │ block1_conv2_act… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, None,      │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, None,      │        512 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, None,      │          0 │ block2_pool[0][0… │
# │                     │ None, 128)        │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, None,      │          0 │ add[0][0]         │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, None,      │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, None,      │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, None,      │          0 │ block3_sepconv1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, None,      │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, None,      │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │     32,768 │ add[0][0]         │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, None,      │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      1,024 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, None,      │          0 │ block3_pool[0][0… │
# │                     │ None, 256)        │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, None,      │          0 │ add_1[0][0]       │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, None,      │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, None,      │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, None,      │          0 │ block4_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, None,      │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, None,      │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │    186,368 │ add_1[0][0]       │
# │                     │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, None,      │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      2,912 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, None,      │          0 │ block4_pool[0][0… │
# │                     │ None, 728)        │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, None,      │          0 │ add_2[0][0]       │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, None,      │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, None,      │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, None,      │          0 │ block5_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, None,      │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, None,      │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, None,      │          0 │ block5_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, None,      │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, None,      │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, None,      │          0 │ block5_sepconv3_… │
# │                     │ None, 728)        │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, None,      │          0 │ add_3[0][0]       │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, None,      │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, None,      │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, None,      │          0 │ block6_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, None,      │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, None,      │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, None,      │          0 │ block6_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, None,      │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, None,      │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, None,      │          0 │ block6_sepconv3_… │
# │                     │ None, 728)        │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, None,      │          0 │ add_4[0][0]       │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, None,      │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, None,      │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, None,      │          0 │ block7_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, None,      │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, None,      │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, None,      │          0 │ block7_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, None,      │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, None,      │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, None,      │          0 │ block7_sepconv3_… │
# │                     │ None, 728)        │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, None,      │          0 │ add_5[0][0]       │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, None,      │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, None,      │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, None,      │          0 │ block8_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, None,      │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, None,      │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, None,      │          0 │ block8_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, None,      │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, None,      │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, None,      │          0 │ block8_sepconv3_… │
# │                     │ None, 728)        │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, None,      │          0 │ add_6[0][0]       │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, None,      │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, None,      │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, None,      │          0 │ block9_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, None,      │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, None,      │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, None,      │          0 │ block9_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, None,      │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, None,      │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, None,      │          0 │ block9_sepconv3_… │
# │                     │ None, 728)        │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, None,      │          0 │ add_7[0][0]       │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, None,      │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, None,      │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, None,      │          0 │ block10_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, None,      │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, None,      │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, None,      │          0 │ block10_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, None,      │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, None,      │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, None,      │          0 │ block10_sepconv3… │
# │                     │ None, 728)        │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, None,      │          0 │ add_8[0][0]       │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, None,      │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, None,      │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, None,      │          0 │ block11_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, None,      │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, None,      │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, None,      │          0 │ block11_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, None,      │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, None,      │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, None,      │          0 │ block11_sepconv3… │
# │                     │ None, 728)        │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, None,      │          0 │ add_9[0][0]       │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, None,      │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, None,      │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, None,      │          0 │ block12_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, None,      │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, None,      │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, None,      │          0 │ block12_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, None,      │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, None,      │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, None,      │          0 │ block12_sepconv3… │
# │                     │ None, 728)        │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, None,      │          0 │ add_10[0][0]      │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, None,      │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, None,      │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, None,      │          0 │ block13_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, None,      │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, None,      │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │    745,472 │ add_10[0][0]      │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, None,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None,      │      4,096 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, None,      │          0 │ block13_pool[0][… │
# │                     │ None, 1024)       │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, None,      │  1,582,080 │ add_11[0][0]      │
# │ (SeparableConv2D)   │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, None,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, None,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, None,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_bn │ (None, None,      │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_a… │ (None, None,      │          0 │ block14_sepconv2… │
# │ (Activation)        │ None, 2048)       │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,861,480 (79.58 MB)
#  Trainable params: 20,806,952 (79.37 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
### Change the model by setting trainable layers in Xception

pre_trained_Xception.trainable = True

for layer in pre_trained_Xception.layers:
  if 'block14_' in layer.name:
    layer.trainable = True
  else:
    layer.trainable = False


input_tensor = keras.Input(shape=(image_size+(3,)), name='input')
x = pre_trained_Xception(input_tensor)
x = keras.layers.Flatten(name='flatten')(x)
x = keras.layers.Dense(16, activation='relu', kernel_initializer='he_normal')(x)
output = keras.layers.Dense(1, activation='sigmoid', name='output', bias_initializer=output_bias)(x)

fine_turned_xception_model = keras.Model(inputs=input_tensor, outputs=output, name='fine_turned_xception_model')
fine_turned_xception_model.summary()
# Out:
# Model: "fine_turned_xception_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 7, 7, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │     1,605,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,467,145 (85.71 MB)
#  Trainable params: 6,354,465 (24.24 MB)
#  Non-trainable params: 16,112,680 (61.46 MB)

# %%
### callback function
model_dir = 'Users/lenhanpham/model_dir'
os.makedirs(model_dir, exist_ok=True)
csv_dir = 'Users/lenhanpham/csv_dir'
os.makedirs(csv_dir, exist_ok=True)

def callbacks(model_name, append_csv=False):
  callb = [
      tf.keras.callbacks.ModelCheckpoint(
          filepath = model_dir + '/' + model_name + '.keras',
          monitor='val_auc',
          save_best_only=True,
          mode='max'
      ),
      tf.keras.callbacks.EarlyStopping(
          monitor='val_auc',
          patience=10,
          mode='max',
          restore_best_weights=True
      ),
      tf.keras.callbacks.CSVLogger(
          filename=csv_dir + '/' + model_name + '.csv',
          separator=',',
          append=append_csv
      )
  ]
  return callb

# %%
### compile the model and train it

fine_turned_xception_model.compile(loss='binary_crossentropy',
                                   optimizer=keras.optimizers.Adam(learning_rate=2e-5),
                                   metrics=model_metrics,
                                   )

fine_turned_xception_model_history = fine_turned_xception_model.fit(augmented_train_generator,
                                                                    validation_data=augmented_validation_generator,
                                                                    callbacks=callbacks('fine_turned_xception_model'),
                                                                    epochs=50)
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 881ms/step - accuracy: 0.6317 - auc: 0.6802 - fn: 208.0448 - fp: 144.5522 - loss: 0.6305 - precision: 0.6009 - recall: 0.5290 - tn: 450.3582 - tp: 283.3433 - val_accuracy: 0.7514 - val_auc: 0.8331 - val_fn: 79.0000 - val_fp: 52.0000 - val_loss: 0.5181 - val_precision: 0.7547 - val_recall: 0.6695 - val_tn: 236.0000 - val_tp: 160.0000
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 59s 852ms/step - accuracy: 0.7857 - auc: 0.8741 - fn: 123.0746 - fp: 101.2537 - loss: 0.4514 - precision: 0.7813 - recall: 0.7390 - tn: 484.9552 - tp: 376.6269 - val_accuracy: 0.7438 - val_auc: 0.8478 - val_fn: 104.0000 - val_fp: 31.0000 - val_loss: 0.5029 - val_precision: 0.8133 - val_recall: 0.5649 - val_tn: 257.0000 - val_tp: 135.0000
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 59s 853ms/step - accuracy: 0.8235 - auc: 0.8978 - fn: 88.7015 - fp: 99.0299 - loss: 0.4082 - precision: 0.8128 - recall: 0.8062 - tn: 487.4328 - tp: 411.4925 - val_accuracy: 0.7818 - val_auc: 0.8610 - val_fn: 62.0000 - val_fp: 53.0000 - val_loss: 0.4638 - val_precision: 0.7696 - val_recall: 0.7406 - val_tn: 235.0000 - val_tp: 177.0000
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 60s 868ms/step - accuracy: 0.8514 - auc: 0.9328 - fn: 80.4627 - fp: 86.0896 - loss: 0.3335 - precision: 0.8334 - recall: 0.8400 - tn: 507.3134 - tp: 413.3582 - val_accuracy: 0.7799 - val_auc: 0.8637 - val_fn: 75.0000 - val_fp: 41.0000 - val_loss: 0.4695 - val_precision: 0.8000 - val_recall: 0.6862 - val_tn: 247.0000 - val_tp: 164.0000
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 813ms/step - accuracy: 0.9018 - auc: 0.9759 - fn: 51.0597 - fp: 50.5970 - loss: 0.2040 - precision: 0.8971 - recall: 0.8859 - tn: 543.8955 - tp: 440.4478 - val_accuracy: 0.8102 - val_auc: 0.8875 - val_fn: 45.0000 - val_fp: 55.0000 - val_loss: 0.4659 - val_precision: 0.7791 - val_recall: 0.8117 - val_tn: 233.0000 - val_tp: 194.0000
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 818ms/step - accuracy: 0.8963 - auc: 0.9698 - fn: 53.9552 - fp: 50.0448 - loss: 0.2274 - precision: 0.9061 - recall: 0.8806 - tn: 526.9850 - tp: 455.0149 - val_accuracy: 0.8102 - val_auc: 0.8920 - val_fn: 50.0000 - val_fp: 50.0000 - val_loss: 0.4484 - val_precision: 0.7908 - val_recall: 0.7908 - val_tn: 238.0000 - val_tp: 189.0000
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 60s 873ms/step - accuracy: 0.9305 - auc: 0.9808 - fn: 38.1194 - fp: 40.8060 - loss: 0.1811 - precision: 0.9114 - recall: 0.9295 - tn: 568.2985 - tp: 439.3134 - val_accuracy: 0.8178 - val_auc: 0.8892 - val_fn: 49.0000 - val_fp: 47.0000 - val_loss: 0.4676 - val_precision: 0.8017 - val_recall: 0.7950 - val_tn: 241.0000 - val_tp: 190.0000
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 876ms/step - accuracy: 0.9195 - auc: 0.9806 - fn: 42.7015 - fp: 50.0149 - loss: 0.1836 - precision: 0.9000 - recall: 0.9217 - tn: 550.3134 - tp: 442.8806 - val_accuracy: 0.8178 - val_auc: 0.8874 - val_fn: 30.0000 - val_fp: 66.0000 - val_loss: 0.4995 - val_precision: 0.7600 - val_recall: 0.8745 - val_tn: 222.0000 - val_tp: 209.0000
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 874ms/step - accuracy: 0.9221 - auc: 0.9816 - fn: 40.8657 - fp: 42.7761 - loss: 0.1815 - precision: 0.9116 - recall: 0.9201 - tn: 546.9254 - tp: 456.6269 - val_accuracy: 0.8140 - val_auc: 0.8921 - val_fn: 61.0000 - val_fp: 37.0000 - val_loss: 0.4945 - val_precision: 0.8279 - val_recall: 0.7448 - val_tn: 251.0000 - val_tp: 178.0000
# Epoch 25/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 898ms/step - accuracy: 0.9223 - auc: 0.9829 - fn: 36.8209 - fp: 43.3134 - loss: 0.1726 - precision: 0.9083 - recall: 0.9250 - tn: 543.5373 - tp: 462.3582 - val_accuracy: 0.8140 - val_auc: 0.8948 - val_fn: 51.0000 - val_fp: 47.0000 - val_loss: 0.4585 - val_precision: 0.8000 - val_recall: 0.7866 - val_tn: 241.0000 - val_tp: 188.0000
# Epoch 26/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 876ms/step - accuracy: 0.9188 - auc: 0.9777 - fn: 40.5075 - fp: 42.9104 - loss: 0.1900 - precision: 0.9132 - recall: 0.9132 - tn: 549.0746 - tp: 453.0597 - val_accuracy: 0.8216 - val_auc: 0.8924 - val_fn: 40.0000 - val_fp: 54.0000 - val_loss: 0.4718 - val_precision: 0.7866 - val_recall: 0.8326 - val_tn: 234.0000 - val_tp: 199.0000
# Epoch 27/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 882ms/step - accuracy: 0.9251 - auc: 0.9810 - fn: 38.7313 - fp: 43.2537 - loss: 0.1797 - precision: 0.9061 - recall: 0.9308 - tn: 551.4478 - tp: 452.8358 - val_accuracy: 0.8046 - val_auc: 0.8803 - val_fn: 62.0000 - val_fp: 41.0000 - val_loss: 0.5087 - val_precision: 0.8119 - val_recall: 0.7406 - val_tn: 247.0000 - val_tp: 177.0000
# Epoch 28/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s
# Epoch 35/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 818ms/step - accuracy: 0.9379 - auc: 0.9858 - fn: 36.1343 - fp: 32.0597 - loss: 0.1544 - precision: 0.9352 - recall: 0.9293 - tn: 558.2836 - tp: 459.7015 - val_accuracy: 0.8197 - val_auc: 0.8897 - val_fn: 49.0000 - val_fp: 46.0000 - val_loss: 0.4921 - val_precision: 0.8051 - val_recall: 0.7950 - val_tn: 242.0000 - val_tp: 190.0000
# Epoch 36/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 828ms/step - accuracy: 0.9383 - auc: 0.9865 - fn: 36.2388 - fp: 35.9851 - loss: 0.1490 - precision: 0.9266 - recall: 0.9342 - tn: 564.5522 - tp: 449.4030 - val_accuracy: 0.8197 - val_auc: 0.8946 - val_fn: 53.0000 - val_fp: 42.0000 - val_loss: 0.5009 - val_precision: 0.8158 - val_recall: 0.7782 - val_tn: 246.0000 - val_tp: 186.0000
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 59s 849ms/step - accuracy: 0.9425 - auc: 0.9884 - fn: 31.0299 - fp: 30.8209 - loss: 0.1426 - precision: 0.9323 - recall: 0.9410 - tn: 563.3582 - tp: 462.1343 - val_accuracy: 0.8121 - val_auc: 0.8932 - val_fn: 61.0000 - val_fp: 38.0000 - val_loss: 0.5138 - val_precision: 0.8241 - val_recall: 0.7448 - val_tn: 250.0000 - val_tp: 178.0000
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 873ms/step - accuracy: 0.9369 - auc: 0.9845 - fn: 27.8209 - fp: 35.6567 - loss: 0.1627 - precision: 0.9277 - recall: 0.9364 - tn: 556.6418 - tp: 467.1642 - val_accuracy: 0.7989 - val_auc: 0.8890 - val_fn: 73.0000 - val_fp: 33.0000 - val_loss: 0.5757 - val_precision: 0.8342 - val_recall: 0.6946 - val_tn: 255.0000 - val_tp: 166.0000
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 874ms/step - accuracy: 0.9511 - auc: 0.9897 - fn: 28.8209 - fp: 25.0299 - loss: 0.1348 - precision: 0.9519 - recall: 0.9410 - tn: 565.6119 - tp: 467.5821 - val_accuracy: 0.8121 - val_auc: 0.8771 - val_fn: 44.0000 - val_fp: 55.0000 - val_loss: 0.5448 - val_precision: 0.7800 - val_recall: 0.8159 - val_tn: 233.0000 - val_tp: 195.0000
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 878ms/step - accuracy: 0.9436 - auc: 0.9897 - fn: 28.9701 - fp: 34.3582 - loss: 0.1339 - precision: 0.9320 - recall: 0.9451 - tn: 558.9254 - tp: 464.8806 - val_accuracy: 0.8102 - val_auc: 0.8836 - val_fn: 64.0000 - val_fp: 36.0000 - val_loss: 0.5564 - val_precision: 0.8294 - val_recall: 0.7322 - val_tn: 252.0000 - val_tp: 175.0000
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 879ms/step - accuracy: 0.9586 - auc: 0.9930 - fn: 25.3731 - fp: 23.2985 - loss: 0.1148 - precision: 0.9565 - recall: 0.9520 - tn: 570.9702 - tp: 465.9702 - val_accuracy: 0.8140 - val_auc: 0.8847 - val_fn: 51.0000 - val_fp: 47.0000 - val_loss: 0.5393 - val_precision: 0.8000 - val_recall: 0.7866 - val_tn: 241.0000 - val_tp: 188.0000
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()

# %%
def plot_training_history(metrics, hist_dict):
  epochs = range(1, len(hist_dict[metrics])+1)
  sns.scatterplot(x=epochs, y=hist_dict[metrics])
  sns.lineplot(x=epochs,y= hist_dict['val_'+metrics])
  plt.title(metrics)
  plt.xlabel('Epoch')
  plt.ylabel(metrics)
  plt.legend(['Train', 'Validation'])

def plot_4metrics(hist_dict):
  plt.figure(figsize=(12,8))
  metrics = ['accuracy', 'loss', 'auc', 'recall']
  for i, metric in enumerate(metrics):
    plt.subplot(2,2,i+1)
    plot_training_history(metric, hist_dict)
  plt.tight_layout()
  plt.show()

plot_4metrics(fine_turned_xception_model_history.history)

# %%
### Load the best model
trained_ftxception_model = tf.keras.models.load_model(model_dir + '/' + 'fine_turned_xception_model' + '.keras')

ft_test_results = trained_ftxception_model.evaluate(augmented_test_generator,return_dict=True)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 539ms/step - accuracy: 0.8414 - auc: 0.9278 - fn: 24.0455 - fp: 38.3636 - loss: 0.3771 - precision: 0.8100 - recall: 0.8699 - tn: 156.6364 - tp: 146.4091

# %%
for metric_name, metric_value in ft_test_results.items():
    print(f'{metric_name:}: {metric_value:.2f}')
# Out:
# accuracy: 0.83
# auc: 0.92
# fn: 45.00
# fp: 70.00
# loss: 0.41
# precision: 0.78
# recall: 0.85
# tn: 290.00
# tp: 255.00

# %%
def get_predictions_and_labels(model, generator):
  prediction_testset = []
  label_testset = []
  num_batch = len(generator)
  i = 0
  for data, label in generator:
    prediction_testset.extend(model.predict(data).flatten())
    label_testset.extend(label)
    i +=1
    if i >= num_batch:
      prediction_testset = np.array(prediction_testset)
      label_testset = np.array(label_testset)
      break
  return prediction_testset, label_testset

test_preds_ftxception, test_labels_ftxception = get_predictions_and_labels(trained_ftxception_model, augmented_test_generator)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
confustion_matrix = tf.math.confusion_matrix(labels=test_labels_ftxception, predictions=test_preds_ftxception>0.5)
confustion_matrix
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[290,  70],
#        [ 45, 255]], dtype=int32)>

# %%
## plot confusion matrix
sns.heatmap(confustion_matrix, annot=True, fmt='d')
plt.title('Confusion matrix @0.5')
plt.ylabel('True class')
# Out:
# Text(46.25, 0.5, 'True class')

# %%
### Plot ROC and AUC
train_preds_ftxception, train_labels_ftxception = get_predictions_and_labels(trained_ftxception_model, augmented_train_generator)
validation_preds_ftxception, validation_labels_ftxception = get_predictions_and_labels(trained_ftxception_model, augmented_validation_generator)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step

# %%
def plot_roc(name, labels, predictions, **kwargs):
    """ Function for plotting the ROC curve. """
    fp, tp, _ = metrics.roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([-0.5, 60])
    plt.ylim([20, 100.5])
    plt.grid(True)
    plt.title('ROC', fontsize=16)
    plt.legend(loc='lower right');


def plot_prc(name, labels, predictions, **kwargs):
    """ Function for plotting the area under the interpolated precision-recall curve (AUPRC). """
    precision, recall, _ = metrics.precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    plt.title('AUPRC', fontsize=16);

# %%
# Plot the ROC and AUPRC
plt.figure(figsize=(16,6))
plt.subplot(1, 2, 1)
plot_roc('Train xception', train_labels_ftxception, train_preds_ftxception, linestyle='--')
plot_roc('Validation xception', validation_labels_ftxception, validation_preds_ftxception, linestyle=':')
plot_roc('Test xception', test_labels_ftxception, test_preds_ftxception)

plt.subplot(1, 2, 2)
plot_prc('Train xception', train_labels_ftxception, train_preds_ftxception, linestyle='--')
plot_prc('Validation xception', validation_labels_ftxception, validation_preds_ftxception, linestyle=':')
plot_prc('Test xception', test_labels_ftxception, test_preds_ftxception)
